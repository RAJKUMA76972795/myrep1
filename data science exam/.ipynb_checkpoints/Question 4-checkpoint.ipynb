# %%
# shared link was "https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2MJzpFA6t0AsBMi8/edit?usp=sharing"
# after click on the above link changed link was "https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2MJzpFA6t0AsBMi8/edit#gid=0"
# Replace “edit#gid” text in the google_sheet_url variable above with “export?format=csv&gid”
# So ,Downloadeable link is "https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2MJzpFA6t0AsBMi8/export?format=csv&gid=0"
import pandas as pd
data1 = pd.read_csv("https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2MJzpFA6t0AsBMi8/export?format=csv&gid=0")
data1
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                  1  WORKING    Missed           5    Missed          9
# 1                  2      NaN    Missed           6    Missed          8
# 2                  3  STUDENT    Missed           9    Missed          6
# 3                  4  STUDENT    Missed           8    Missed          8
# 4                  5  WORKING    Missed           9    Missed          5
# 5                  6      NaN    Missed           8    Missed          8
# 6                  7  STUDENT  Attended          10  Attended          5
# 7                  8  STUDENT    Missed           8    Missed          8
# 8                  9   IGNORE    Missed           5    Missed          8
# 9                 10      NaN    Missed           8    Missed          7
# 10                11  STUDENT  Attended           6  Attended          8
# 11                12  STUDENT  Attended           5  Attended          9
# ...

# %%
data2=pd.read_csv("https://docs.google.com/spreadsheets/d/1Y_g6LQI2GLqpKf-fj-rH7D9gfnP2MJzpFA6t0AsBMi8/export?format=csv&gid=1548342679")
data2
# Out:
#     Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                  1      NaN  Attended           6  Attended          6
# 1                  2      NaN  Attended          10  Attended          6
# 2                  3  STUDENT    Missed           5    Missed          5
# 3                  4      NaN  Attended          10  Attended         10
# 4                  5  WORKING  Attended           6  Attended          5
# ..               ...      ...       ...         ...       ...        ...
# 65                66   IGNORE    Missed          10    Missed         10
# 66                67  STUDENT    Missed           6    Missed          5
# 67                68      NaN  Attended          10  Attended          5
# 68                69      NaN  Attended          10  Attended          5
# 69                70      NaN  Attended           6  Attended          6
#
#     08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# ...

# %%
# "https://docs.google.com/spreadsheets/d/1r-WNWqIACWg8T6Q253jKzHBjRzWLPC0yQoFH5RwtiUY/edit?usp=sharing"
# sample from google sheet to pandas stock market data
# "https://docs.google.com/spreadsheets/d/1r-WNWqIACWg8T6Q253jKzHBjRzWLPC0yQoFH5RwtiUY/edit#gid=0"
# "https://docs.google.com/spreadsheets/d/1r-WNWqIACWg8T6Q253jKzHBjRzWLPC0yQoFH5RwtiUY/export?format=csv&gid=0"
data3=pd.read_csv("https://docs.google.com/spreadsheets/d/1r-WNWqIACWg8T6Q253jKzHBjRzWLPC0yQoFH5RwtiUY/export?format=csv&gid=0")
data3
# Out:
#         SYMBOL       OPEN       HIGH        LOW PREV. CLOSE        LTP  \
# 0     NIFTY 50  17,001.55  17,309.15  16,836.80   17,149.10  17,277.95
# 1       MARUTI   7,990.00   8,664.00   7,887.90    8,052.30   8,650.10
# 2     AXISBANK        714        755      708.6       704.6     750.55
# 3         SBIN        490      517.5        489      494.15     513.35
# 4   INDUSINDBK     842.35      886.9        842      851.25      881.6
# 5          UPL      754.5     795.15      746.1       762.6      789.4
# 6    COALINDIA        155      161.6      154.3       156.3        161
# 7   BHARTIARTL        684     720.45     682.15       689.9      709.4
# 8   TATACONSUM        690     709.95        675      691.45      708.2
# 9         BPCL      372.1      383.8        368       373.1        382
# 10  HEROMOTOCO   2,704.10   2,789.00   2,652.85    2,706.20   2,769.85
# 11  TATAMOTORS      473.8      492.5     467.65      478.45      489.4
# ...

# %%
data4=pd.read_csv("https://docs.google.com/spreadsheets/d/1r-WNWqIACWg8T6Q253jKzHBjRzWLPC0yQoFH5RwtiUY/export?format=csv&usp=sharing")
data4
# Out:
#         SYMBOL       OPEN       HIGH        LOW PREV. CLOSE        LTP  \
# 0     NIFTY 50  17,001.55  17,309.15  16,836.80   17,149.10  17,277.95
# 1       MARUTI   7,990.00   8,664.00   7,887.90    8,052.30   8,650.10
# 2     AXISBANK        714        755      708.6       704.6     750.55
# 3         SBIN        490      517.5        489      494.15     513.35
# 4   INDUSINDBK     842.35      886.9        842      851.25      881.6
# 5          UPL      754.5     795.15      746.1       762.6      789.4
# 6    COALINDIA        155      161.6      154.3       156.3        161
# 7   BHARTIARTL        684     720.45     682.15       689.9      709.4
# 8   TATACONSUM        690     709.95        675      691.45      708.2
# 9         BPCL      372.1      383.8        368       373.1        382
# 10  HEROMOTOCO   2,704.10   2,789.00   2,652.85    2,706.20   2,769.85
# 11  TATAMOTORS      473.8      492.5     467.65      478.45      489.4
# ...
